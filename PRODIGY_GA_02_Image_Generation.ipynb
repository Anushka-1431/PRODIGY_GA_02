# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka-1431/PRODIGY_GA_02/blob/main/PRODIGY_GA_02_Image_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print(torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

# %%
# !pip install -q diffusers transformers accelerate safetensors

# %%
import diffusers
import torch

print("Libraries Installed Successfully")
print("Diffusers Version:", diffusers.__version__)

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
)

pipe = pipe.to("cuda")

print("Stable Diffusion Model Loaded Successfully")

# %%
prompts = [
    "A futuristic AI city at night with glowing lights",
    "A robot painting a digital artwork in a studio",
    "An AI laboratory with holograms and scientists"
]

for i, prompt in enumerate(prompts):
    img = pipe(prompt).images[0]
    img.save(f"image_{i+1}.png")
    print(f"Saved image_{i+1}.png")

# %%
from PIL import Image
from IPython.display import display

for i in range(1, 4):
    print(f"\nImage {i}")

    img = Image.open(f"image_{i}.png")

    display(img)

# %%
from google.colab import files

files.download("image_1.png")
files.download("image_2.png")
files.download("image_3.png")
